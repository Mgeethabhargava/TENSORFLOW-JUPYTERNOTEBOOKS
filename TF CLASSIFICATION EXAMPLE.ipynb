# %%
import pandas as pd
diabetes = pd.read_csv('1.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min())/(x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group',hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,assigned_group,age_bucket]

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
#labels

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x_data,labels,test_size=0.3,random_state=101)

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Public\\Documents\\Wondershare\\CreatorTemp\\tmptnbdutm6', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:518: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\ftrl.py:143: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6\model.ckpt.
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 116.827
# INFO:tensorflow:loss = 0.71839523, step = 100 (0.856 sec)
# INFO:tensorflow:global_step/sec: 136.986
# INFO:tensorflow:loss = 0.6197108, step = 200 (0.729 sec)
# INFO:tensorflow:global_step/sec: 142.857
# INFO:tensorflow:loss = 0.6517483, step = 300 (0.700 sec)
# INFO:tensorflow:global_step/sec: 160.256
# INFO:tensorflow:loss = 0.4346195, step = 400 (0.624 sec)
# INFO:tensorflow:global_step/sec: 154.799
# INFO:tensorflow:loss = 0.35723525, step = 500 (0.647 sec)
# INFO:tensorflow:global_step/sec: 156.25
# INFO:tensorflow:loss = 0.5712882, step = 600 (0.639 sec)
# INFO:tensorflow:global_step/sec: 161.812
# INFO:tensorflow:loss = 0.46162763, step = 700 (0.619 sec)
# INFO:tensorflow:global_step/sec: 155.763
# INFO:tensorflow:loss = 0.5075878, step = 800 (0.641 sec)
# INFO:tensorflow:global_step/sec: 164.203
# INFO:tensorflow:loss = 0.4286619, step = 900 (0.610 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.78041625.

# %%
eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-05-16T17:43:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.17883s
# INFO:tensorflow:Finished evaluation at 2020-05-16-17:43:53
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7229437, accuracy_baseline = 0.64935064, auc = 0.7985185, auc_precision_recall = 0.6378166, average_loss = 0.5283677, global_step = 1000, label/mean = 0.35064936, loss = 0.52876776, precision = 0.6603774, prediction/mean = 0.33521187, recall = 0.43209878
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.7229437,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.7985185,
#  'auc_precision_recall': 0.6378166,
#  'average_loss': 0.5283677,
#  'label/mean': 0.35064936,
#  'loss': 0.52876776,
#  'precision': 0.6603774,
#  'prediction/mean': 0.33521187,
#  'recall': 0.43209878,
#  'global_step': 1000}

# %%
pred_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
my_pred
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Public\Documents\Wondershare\CreatorTemp\tmptnbdutm6\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([-0.00922012], dtype=float32),
#   'logistic': array([0.49769497], dtype=float32),
#   'probabilities': array([0.502305  , 0.49769497], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3007121], dtype=float32),
#   'logistic': array([0.5746166], dtype=float32),
#   'probabilities': array([0.4253834, 0.5746166], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.69354385], dtype=float32),
#   'logistic': array([0.3332452], dtype=float32),
#   'probabilities': array([0.66675484, 0.3332452 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8239026], dtype=float32),
#   'logistic': array([0.30493587], dtype=float32),
#   'probabilities': array([0.6950641 , 0.30493587], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8067505], dtype=float32),
#   'logistic': array([0.14103131], dtype=float32),
#   'probabilities': array([0.85896873, 0.14103131], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4412166], dtype=float32),
#   'logistic': array([0.6085489], dtype=float32),
#   'probabilities': array([0.39145115, 0.6085489 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19012749], dtype=float32),
#   'logistic': array([0.5473892], dtype=float32),
#   'probabilities': array([0.45261076, 0.5473892 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7994016], dtype=float32),
#   'logistic': array([0.31015354], dtype=float32),
#   'probabilities': array([0.68984646, 0.31015354], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2852695], dtype=float32),
#   'logistic': array([0.21665458], dtype=float32),
#   'probabilities': array([0.7833454 , 0.21665458], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1254319], dtype=float32),
#   'logistic': array([0.2450051], dtype=float32),
#   'probabilities': array([0.7549949 , 0.24500512], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9414122], dtype=float32),
#   'logistic': array([0.12549278], dtype=float32),
#   'probabilities': array([0.8745072 , 0.12549278], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.714641], dtype=float32),
#   'logistic': array([0.15256272], dtype=float32),
#   'probabilities': array([0.84743726, 0.15256274], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0572578], dtype=float32),
#   'logistic': array([0.25783384], dtype=float32),
#   'probabilities': array([0.7421662 , 0.25783384], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08639443], dtype=float32),
#   'logistic': array([0.52158517], dtype=float32),
#   'probabilities': array([0.47841483, 0.52158517], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6006212], dtype=float32),
#   'logistic': array([0.16789481], dtype=float32),
#   'probabilities': array([0.83210516, 0.1678948 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8669151], dtype=float32),
#   'logistic': array([0.29589662], dtype=float32),
#   'probabilities': array([0.70410335, 0.29589662], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.78022516], dtype=float32),
#   'logistic': array([0.31427133], dtype=float32),
#   'probabilities': array([0.68572867, 0.31427136], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9719352], dtype=float32),
#   'logistic': array([0.12218118], dtype=float32),
#   'probabilities': array([0.8778188 , 0.12218118], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.75811446], dtype=float32),
#   'logistic': array([0.31905577], dtype=float32),
#   'probabilities': array([0.68094426, 0.31905577], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8055904], dtype=float32),
#   'logistic': array([0.14117192], dtype=float32),
#   'probabilities': array([0.8588281 , 0.14117192], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3834499], dtype=float32),
#   'logistic': array([0.20045549], dtype=float32),
#   'probabilities': array([0.79954445, 0.2004555 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0359535], dtype=float32),
#   'logistic': array([0.2619315], dtype=float32),
#   'probabilities': array([0.73806846, 0.2619315 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4048717], dtype=float32),
#   'logistic': array([0.59985757], dtype=float32),
#   'probabilities': array([0.40014243, 0.59985757], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.36953], dtype=float32),
#   'logistic': array([0.2026958], dtype=float32),
#   'probabilities': array([0.7973042 , 0.20269579], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6535773], dtype=float32),
#   'logistic': array([0.16062605], dtype=float32),
#   'probabilities': array([0.839374  , 0.16062605], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8421681], dtype=float32),
#   'logistic': array([0.6989217], dtype=float32),
#   'probabilities': array([0.30107835, 0.6989217 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6387618], dtype=float32),
#   'logistic': array([0.16263363], dtype=float32),
#   'probabilities': array([0.83736634, 0.16263363], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.94658625], dtype=float32),
#   'logistic': array([0.27957186], dtype=float32),
#   'probabilities': array([0.72042817, 0.27957186], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1820693], dtype=float32),
#   'logistic': array([0.10137227], dtype=float32),
#   'probabilities': array([0.8986277 , 0.10137226], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.13862777], dtype=float32),
#   'logistic': array([0.5346015], dtype=float32),
#   'probabilities': array([0.46539843, 0.5346015 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.226019], dtype=float32),
#   'logistic': array([0.9025618], dtype=float32),
#   'probabilities': array([0.09743819, 0.9025618 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.476597], dtype=float32),
#   'logistic': array([0.383056], dtype=float32),
#   'probabilities': array([0.61694396, 0.383056  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.85934156], dtype=float32),
#   'logistic': array([0.29747695], dtype=float32),
#   'probabilities': array([0.70252305, 0.29747692], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05311203], dtype=float32),
#   'logistic': array([0.5132749], dtype=float32),
#   'probabilities': array([0.48672512, 0.5132749 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3201904], dtype=float32),
#   'logistic': array([0.21078663], dtype=float32),
#   'probabilities': array([0.78921336, 0.21078661], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6636379], dtype=float32),
#   'logistic': array([0.3399229], dtype=float32),
#   'probabilities': array([0.6600771 , 0.33992288], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.13737756], dtype=float32),
#   'logistic': array([0.46570954], dtype=float32),
#   'probabilities': array([0.5342905, 0.4657095], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34165716], dtype=float32),
#   'logistic': array([0.584593], dtype=float32),
#   'probabilities': array([0.415407, 0.584593], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.86987793], dtype=float32),
#   'logistic': array([0.7047203], dtype=float32),
#   'probabilities': array([0.2952797, 0.7047203], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7927454], dtype=float32),
#   'logistic': array([0.31157947], dtype=float32),
#   'probabilities': array([0.68842053, 0.31157947], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6107125], dtype=float32),
#   'logistic': array([0.1664897], dtype=float32),
#   'probabilities': array([0.83351034, 0.16648972], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06486452], dtype=float32),
#   'logistic': array([0.48378956], dtype=float32),
#   'probabilities': array([0.5162105 , 0.48378956], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8078358], dtype=float32),
#   'logistic': array([0.1408999], dtype=float32),
#   'probabilities': array([0.8591001 , 0.14089988], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.08826888], dtype=float32),
#   'logistic': array([0.4779471], dtype=float32),
#   'probabilities': array([0.5220529 , 0.47794712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.923485], dtype=float32),
#   'logistic': array([0.12747344], dtype=float32),
#   'probabilities': array([0.8725265 , 0.12747343], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9915752], dtype=float32),
#   'logistic': array([0.12009031], dtype=float32),
#   'probabilities': array([0.87990963, 0.12009031], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2576505], dtype=float32),
#   'logistic': array([0.56405866], dtype=float32),
#   'probabilities': array([0.43594134, 0.56405866], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5585586], dtype=float32),
#   'logistic': array([0.17385358], dtype=float32),
#   'probabilities': array([0.8261464 , 0.17385358], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5601805], dtype=float32),
#   'logistic': array([0.17362075], dtype=float32),
#   'probabilities': array([0.82637924, 0.17362073], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9432709], dtype=float32),
#   'logistic': array([0.12528895], dtype=float32),
#   'probabilities': array([0.874711  , 0.12528895], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5802842], dtype=float32),
#   'logistic': array([0.17075524], dtype=float32),
#   'probabilities': array([0.8292448 , 0.17075524], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3222123], dtype=float32),
#   'logistic': array([0.21045046], dtype=float32),
#   'probabilities': array([0.7895496 , 0.21045046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1583053], dtype=float32),
#   'logistic': array([0.23897535], dtype=float32),
#   'probabilities': array([0.76102465, 0.23897536], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6674672], dtype=float32),
#   'logistic': array([0.3390642], dtype=float32),
#   'probabilities': array([0.6609358, 0.3390642], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0421047], dtype=float32),
#   'logistic': array([0.11485259], dtype=float32),
#   'probabilities': array([0.88514745, 0.11485259], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2905176], dtype=float32),
#   'logistic': array([0.21576521], dtype=float32),
#   'probabilities': array([0.78423476, 0.21576522], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.403868], dtype=float32),
#   'logistic': array([0.19720304], dtype=float32),
#   'probabilities': array([0.802797  , 0.19720304], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3861005], dtype=float32),
#   'logistic': array([0.20003101], dtype=float32),
#   'probabilities': array([0.799969  , 0.20003103], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2793296], dtype=float32),
#   'logistic': array([0.4306181], dtype=float32),
#   'probabilities': array([0.5693819 , 0.43061814], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6852582], dtype=float32),
#   'logistic': array([0.15640046], dtype=float32),
#   'probabilities': array([0.84359956, 0.15640046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3405923], dtype=float32),
#   'logistic': array([0.20741268], dtype=float32),
#   'probabilities': array([0.79258734, 0.20741268], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3385495], dtype=float32),
#   'logistic': array([0.5838381], dtype=float32),
#   'probabilities': array([0.41616186, 0.5838381 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31795526], dtype=float32),
#   'logistic': array([0.57882583], dtype=float32),
#   'probabilities': array([0.42117414, 0.57882583], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.17342705], dtype=float32),
#   'logistic': array([0.45675159], dtype=float32),
#   'probabilities': array([0.5432484 , 0.45675159], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.69131786], dtype=float32),
#   'logistic': array([0.33374], dtype=float32),
#   'probabilities': array([0.66626   , 0.33373994], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.30892366], dtype=float32),
#   'logistic': array([0.42337745], dtype=float32),
#   'probabilities': array([0.5766225 , 0.42337748], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5956321], dtype=float32),
#   'logistic': array([0.16859297], dtype=float32),
#   'probabilities': array([0.831407  , 0.16859297], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5903943], dtype=float32),
#   'logistic': array([0.16932844], dtype=float32),
#   'probabilities': array([0.83067155, 0.16932842], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7983942], dtype=float32),
#   'logistic': array([0.14204665], dtype=float32),
#   'probabilities': array([0.85795337, 0.14204663], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.017208], dtype=float32),
#   'logistic': array([0.11740799], dtype=float32),
#   'probabilities': array([0.882592  , 0.11740799], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21706045], dtype=float32),
#   'logistic': array([0.55405307], dtype=float32),
#   'probabilities': array([0.44594696, 0.55405307], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3892533], dtype=float32),
#   'logistic': array([0.199527], dtype=float32),
#   'probabilities': array([0.800473, 0.199527], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4103195], dtype=float32),
#   'logistic': array([0.39883548], dtype=float32),
#   'probabilities': array([0.6011645, 0.3988355], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.15378761], dtype=float32),
#   'logistic': array([0.5383713], dtype=float32),
#   'probabilities': array([0.4616287, 0.5383713], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9132081], dtype=float32),
#   'logistic': array([0.2863438], dtype=float32),
#   'probabilities': array([0.7136562, 0.2863438], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2887038], dtype=float32),
#   'logistic': array([0.5716788], dtype=float32),
#   'probabilities': array([0.4283212, 0.5716788], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9320712], dtype=float32),
#   'logistic': array([0.1265215], dtype=float32),
#   'probabilities': array([0.8734785, 0.1265215], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3278247], dtype=float32),
#   'logistic': array([0.58123004], dtype=float32),
#   'probabilities': array([0.41877002, 0.58123004], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0011148], dtype=float32),
#   'logistic': array([0.11908592], dtype=float32),
#   'probabilities': array([0.88091403, 0.11908592], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.05143452], dtype=float32),
#   'logistic': array([0.48714423], dtype=float32),
#   'probabilities': array([0.5128558 , 0.48714423], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.89728], dtype=float32),
#   'logistic': array([0.2896098], dtype=float32),
#   'probabilities': array([0.7103902 , 0.28960976], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7867126], dtype=float32),
#   'logistic': array([0.14347623], dtype=float32),
#   'probabilities': array([0.85652375, 0.14347623], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01483166], dtype=float32),
#   'logistic': array([0.5037078], dtype=float32),
#   'probabilities': array([0.49629214, 0.5037078 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17797744], dtype=float32),
#   'logistic': array([0.54437727], dtype=float32),
#   'probabilities': array([0.4556227 , 0.54437727], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.02525723], dtype=float32),
#   'logistic': array([0.49368602], dtype=float32),
#   'probabilities': array([0.506314  , 0.49368602], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6692572], dtype=float32),
#   'logistic': array([0.15852325], dtype=float32),
#   'probabilities': array([0.8414768 , 0.15852325], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7092862], dtype=float32),
#   'logistic': array([0.3297566], dtype=float32),
#   'probabilities': array([0.67024344, 0.3297566 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8010664], dtype=float32),
#   'logistic': array([0.14172131], dtype=float32),
#   'probabilities': array([0.8582787, 0.1417213], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.55763865], dtype=float32),
#   'logistic': array([0.635906], dtype=float32),
#   'probabilities': array([0.364094, 0.635906], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0705162], dtype=float32),
#   'logistic': array([0.74469507], dtype=float32),
#   'probabilities': array([0.2553049 , 0.74469507], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3402213], dtype=float32),
#   'logistic': array([0.58424425], dtype=float32),
#   'probabilities': array([0.41575572, 0.58424425], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3590657], dtype=float32),
#   'logistic': array([0.20439221], dtype=float32),
#   'probabilities': array([0.7956078 , 0.20439221], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.29017484], dtype=float32),
#   'logistic': array([0.42796108], dtype=float32),
#   'probabilities': array([0.57203895, 0.42796108], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5960566], dtype=float32),
#   'logistic': array([0.3552464], dtype=float32),
#   'probabilities': array([0.6447536, 0.3552464], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44186163], dtype=float32),
#   'logistic': array([0.39129743], dtype=float32),
#   'probabilities': array([0.60870254, 0.39129746], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.745375], dtype=float32),
#   'logistic': array([0.32182992], dtype=float32),
#   'probabilities': array([0.6781701, 0.3218299], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3732381], dtype=float32),
#   'logistic': array([0.4077588], dtype=float32),
#   'probabilities': array([0.5922412, 0.4077588], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8415214], dtype=float32),
#   'logistic': array([0.13687146], dtype=float32),
#   'probabilities': array([0.86312854, 0.13687146], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06227887], dtype=float32),
#   'logistic': array([0.5155647], dtype=float32),
#   'probabilities': array([0.48443532, 0.5155647 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00587726], dtype=float32),
#   'logistic': array([0.49853066], dtype=float32),
#   'probabilities': array([0.5014693 , 0.49853072], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1970975], dtype=float32),
#   'logistic': array([0.23199195], dtype=float32),
#   'probabilities': array([0.76800805, 0.23199196], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6839284], dtype=float32),
#   'logistic': array([0.156576], dtype=float32),
#   'probabilities': array([0.8434241, 0.156576 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6437241], dtype=float32),
#   'logistic': array([0.16195896], dtype=float32),
#   'probabilities': array([0.838041  , 0.16195896], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0702109], dtype=float32),
#   'logistic': array([0.25536296], dtype=float32),
#   'probabilities': array([0.744637  , 0.25536296], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6488814], dtype=float32),
#   'logistic': array([0.34324166], dtype=float32),
#   'probabilities': array([0.6567583 , 0.34324166], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9492924], dtype=float32),
#   'logistic': array([0.12463053], dtype=float32),
#   'probabilities': array([0.8753695 , 0.12463053], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8016373], dtype=float32),
#   'logistic': array([0.3096754], dtype=float32),
#   'probabilities': array([0.6903246, 0.3096754], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2493788], dtype=float32),
#   'logistic': array([0.22280769], dtype=float32),
#   'probabilities': array([0.7771923 , 0.22280768], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2764888], dtype=float32),
#   'logistic': array([0.09308896], dtype=float32),
#   'probabilities': array([0.9069111 , 0.09308896], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9732819], dtype=float32),
#   'logistic': array([0.12203682], dtype=float32),
#   'probabilities': array([0.8779632 , 0.12203681], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8456962], dtype=float32),
#   'logistic': array([0.6996636], dtype=float32),
#   'probabilities': array([0.30033648, 0.6996636 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6099981], dtype=float32),
#   'logistic': array([0.16658887], dtype=float32),
#   'probabilities': array([0.8334111 , 0.16658887], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9915364], dtype=float32),
#   'logistic': array([0.12009443], dtype=float32),
#   'probabilities': array([0.8799056 , 0.12009442], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8358257], dtype=float32),
#   'logistic': array([0.13754573], dtype=float32),
#   'probabilities': array([0.8624543 , 0.13754573], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2621889], dtype=float32),
#   'logistic': array([0.43482572], dtype=float32),
#   'probabilities': array([0.5651743, 0.4348257], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.34719664], dtype=float32),
#   'logistic': array([0.4140624], dtype=float32),
#   'probabilities': array([0.5859376 , 0.41406238], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.270343], dtype=float32),
#   'logistic': array([0.21919857], dtype=float32),
#   'probabilities': array([0.7808015 , 0.21919855], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.36625087], dtype=float32),
#   'logistic': array([0.40944725], dtype=float32),
#   'probabilities': array([0.59055275, 0.40944722], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6098686], dtype=float32),
#   'logistic': array([0.16660684], dtype=float32),
#   'probabilities': array([0.83339316, 0.16660686], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2581782], dtype=float32),
#   'logistic': array([0.22128765], dtype=float32),
#   'probabilities': array([0.77871233, 0.22128767], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14178765], dtype=float32),
#   'logistic': array([0.46461236], dtype=float32),
#   'probabilities': array([0.53538764, 0.46461236], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.32774317], dtype=float32),
#   'logistic': array([0.41878986], dtype=float32),
#   'probabilities': array([0.58121014, 0.41878983], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9562333], dtype=float32),
#   'logistic': array([0.12387528], dtype=float32),
#   'probabilities': array([0.87612474, 0.12387528], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6103517], dtype=float32),
#   'logistic': array([0.351979], dtype=float32),
#   'probabilities': array([0.64802104, 0.351979  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5041108], dtype=float32),
#   'logistic': array([0.6234249], dtype=float32),
#   'probabilities': array([0.37657508, 0.6234249 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.16589558], dtype=float32),
#   'logistic': array([0.45862094], dtype=float32),
#   'probabilities': array([0.5413791 , 0.45862097], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7114934], dtype=float32),
#   'logistic': array([0.32926896], dtype=float32),
#   'probabilities': array([0.67073107, 0.32926893], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11169136], dtype=float32),
#   'logistic': array([0.52789384], dtype=float32),
#   'probabilities': array([0.47210616, 0.52789384], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2966391], dtype=float32),
#   'logistic': array([0.21473119], dtype=float32),
#   'probabilities': array([0.7852688, 0.2147312], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5966804], dtype=float32),
#   'logistic': array([0.1684461], dtype=float32),
#   'probabilities': array([0.83155394, 0.1684461 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9644771], dtype=float32),
#   'logistic': array([0.12298334], dtype=float32),
#   'probabilities': array([0.87701666, 0.12298334], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1189353], dtype=float32),
#   'logistic': array([0.24620882], dtype=float32),
#   'probabilities': array([0.75379115, 0.2462088 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.21504909], dtype=float32),
#   'logistic': array([0.44644397], dtype=float32),
#   'probabilities': array([0.553556  , 0.44644397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5577463], dtype=float32),
#   'logistic': array([0.6359309], dtype=float32),
#   'probabilities': array([0.36406907, 0.6359309 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3553263], dtype=float32),
#   'logistic': array([0.20500095], dtype=float32),
#   'probabilities': array([0.79499906, 0.20500094], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7027582], dtype=float32),
#   'logistic': array([0.15410538], dtype=float32),
#   'probabilities': array([0.8458946 , 0.15410537], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.48484176], dtype=float32),
#   'logistic': array([0.38110948], dtype=float32),
#   'probabilities': array([0.6188905 , 0.38110945], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3206027], dtype=float32),
#   'logistic': array([0.21071805], dtype=float32),
#   'probabilities': array([0.78928196, 0.21071805], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8278635], dtype=float32),
#   'logistic': array([0.13849299], dtype=float32),
#   'probabilities': array([0.861507  , 0.13849299], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5467798], dtype=float32),
#   'logistic': array([0.17555186], dtype=float32),
#   'probabilities': array([0.8244481 , 0.17555186], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9881581], dtype=float32),
#   'logistic': array([0.12045185], dtype=float32),
#   'probabilities': array([0.8795482 , 0.12045185], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
# ...
#  {'logits': array([0.6805432], dtype=float32),
#   'logistic': array([0.66385996], dtype=float32),
#   'probabilities': array([0.33614004, 0.66385996], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.98984], dtype=float32),
#   'logistic': array([0.12027379], dtype=float32),
#   'probabilities': array([0.8797262 , 0.12027378], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8354652], dtype=float32),
#   'logistic': array([0.13758852], dtype=float32),
#   'probabilities': array([0.86241156, 0.1375885 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4205079], dtype=float32),
#   'logistic': array([0.19458197], dtype=float32),
#   'probabilities': array([0.8054181 , 0.19458199], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8807359], dtype=float32),
#   'logistic': array([0.2930253], dtype=float32),
#   'probabilities': array([0.7069747, 0.2930253], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.69503635], dtype=float32),
#   'logistic': array([0.33291364], dtype=float32),
#   'probabilities': array([0.66708636, 0.33291364], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0606693], dtype=float32),
#   'logistic': array([0.51516265], dtype=float32),
#   'probabilities': array([0.4848373 , 0.51516265], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01318562], dtype=float32),
#   'logistic': array([0.5032964], dtype=float32),
#   'probabilities': array([0.49670365, 0.5032964 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.60607827], dtype=float32),
#   'logistic': array([0.35295436], dtype=float32),
#   'probabilities': array([0.6470457, 0.3529543], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8136782], dtype=float32),
#   'logistic': array([0.30710724], dtype=float32),
#   'probabilities': array([0.69289273, 0.30710724], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.694433], dtype=float32),
#   'logistic': array([0.33304766], dtype=float32),
#   'probabilities': array([0.6669524, 0.3330477], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5228345], dtype=float32),
#   'logistic': array([0.1790445], dtype=float32),
#   'probabilities': array([0.8209555 , 0.17904451], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30001032], dtype=float32),
#   'logistic': array([0.574445], dtype=float32),
#   'probabilities': array([0.42555493, 0.574445  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9772644], dtype=float32),
#   'logistic': array([0.12161076], dtype=float32),
#   'probabilities': array([0.8783893 , 0.12161075], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2218537], dtype=float32),
#   'logistic': array([0.22761038], dtype=float32),
#   'probabilities': array([0.7723896 , 0.22761038], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01154113], dtype=float32),
#   'logistic': array([0.5028853], dtype=float32),
#   'probabilities': array([0.49711475, 0.5028853 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8998424], dtype=float32),
#   'logistic': array([0.28908288], dtype=float32),
#   'probabilities': array([0.7109171 , 0.28908288], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4463596], dtype=float32),
#   'logistic': array([0.19056244], dtype=float32),
#   'probabilities': array([0.8094376 , 0.19056246], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1459168], dtype=float32),
#   'logistic': array([0.24123569], dtype=float32),
#   'probabilities': array([0.7587643 , 0.24123567], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1754211], dtype=float32),
#   'logistic': array([0.2358765], dtype=float32),
#   'probabilities': array([0.76412356, 0.23587649], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9116316], dtype=float32),
#   'logistic': array([0.12879767], dtype=float32),
#   'probabilities': array([0.87120235, 0.12879767], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4348943], dtype=float32),
#   'logistic': array([0.19233724], dtype=float32),
#   'probabilities': array([0.8076627 , 0.19233723], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02946568], dtype=float32),
#   'logistic': array([0.5073659], dtype=float32),
#   'probabilities': array([0.49263412, 0.5073659 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.636425], dtype=float32),
#   'logistic': array([0.6539449], dtype=float32),
#   'probabilities': array([0.34605512, 0.6539449 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2669629], dtype=float32),
#   'logistic': array([0.5663471], dtype=float32),
#   'probabilities': array([0.43365285, 0.5663471 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.60687625], dtype=float32),
#   'logistic': array([0.6472279], dtype=float32),
#   'probabilities': array([0.3527721, 0.6472279], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39756936], dtype=float32),
#   'logistic': array([0.40189645], dtype=float32),
#   'probabilities': array([0.5981035 , 0.40189648], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9824015], dtype=float32),
#   'logistic': array([0.27241552], dtype=float32),
#   'probabilities': array([0.7275845 , 0.27241552], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.18899858], dtype=float32),
#   'logistic': array([0.4528905], dtype=float32),
#   'probabilities': array([0.5471095, 0.4528905], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5161886], dtype=float32),
#   'logistic': array([0.18002345], dtype=float32),
#   'probabilities': array([0.81997657, 0.18002346], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7531105], dtype=float32),
#   'logistic': array([0.14765531], dtype=float32),
#   'probabilities': array([0.85234475, 0.14765531], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5699824], dtype=float32),
#   'logistic': array([0.17221889], dtype=float32),
#   'probabilities': array([0.82778114, 0.1722189 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.20875716], dtype=float32),
#   'logistic': array([0.44799942], dtype=float32),
#   'probabilities': array([0.5520006 , 0.44799942], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.7888846], dtype=float32),
#   'logistic': array([0.05792779], dtype=float32),
#   'probabilities': array([0.9420723 , 0.05792779], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1576446], dtype=float32),
#   'logistic': array([0.23909555], dtype=float32),
#   'probabilities': array([0.7609045 , 0.23909554], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5996417], dtype=float32),
#   'logistic': array([0.16803169], dtype=float32),
#   'probabilities': array([0.83196825, 0.16803169], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.11276], dtype=float32),
#   'logistic': array([0.24735671], dtype=float32),
#   'probabilities': array([0.75264335, 0.2473567 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.214782], dtype=float32),
#   'logistic': array([0.22885603], dtype=float32),
#   'probabilities': array([0.771144  , 0.22885603], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0882561], dtype=float32),
#   'logistic': array([0.2519468], dtype=float32),
#   'probabilities': array([0.7480532, 0.2519468], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.88092935], dtype=float32),
#   'logistic': array([0.7070148], dtype=float32),
#   'probabilities': array([0.29298523, 0.7070148 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6754467], dtype=float32),
#   'logistic': array([0.15769935], dtype=float32),
#   'probabilities': array([0.84230065, 0.15769935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0368323], dtype=float32),
#   'logistic': array([0.11538967], dtype=float32),
#   'probabilities': array([0.8846103 , 0.11538968], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0878104], dtype=float32),
#   'logistic': array([0.5219385], dtype=float32),
#   'probabilities': array([0.47806147, 0.5219385 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.25283408], dtype=float32),
#   'logistic': array([0.43712604], dtype=float32),
#   'probabilities': array([0.5628739 , 0.43712604], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3904997], dtype=float32),
#   'logistic': array([0.80067205], dtype=float32),
#   'probabilities': array([0.19932799, 0.80067205], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.35814917], dtype=float32),
#   'logistic': array([0.58859235], dtype=float32),
#   'probabilities': array([0.41140765, 0.58859235], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.032519], dtype=float32),
#   'logistic': array([0.11583068], dtype=float32),
#   'probabilities': array([0.88416934, 0.11583067], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.33637023], dtype=float32),
#   'logistic': array([0.5833085], dtype=float32),
#   'probabilities': array([0.41669148, 0.5833085 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # neural networks classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbnvuagtv
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Public\\Documents\\Wondershare\\CreatorTemp\\tmpbnvuagtv', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-f8c9922af341> in <module>
# ----> 1 dnn_model.train(input_fn=input_func,steps=1000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     372
#     373       saving_listeners = _check_listeners_type(saving_listeners)
# --> 374       loss = self._train_model(input_fn, hooks, saving_listeners)
#     375       logging.info('Loss for final step: %s.', loss)
#     376       return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1162       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1163     else:
# -> 1164       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1165
#    1166   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1192       worker_hooks.extend(input_hooks)
#    1193       estimator_spec = self._call_model_fn(
# -> 1194           features, labels, ModeKeys.TRAIN, self.config)
#    1195       global_step_tensor = training_util.get_global_step(g)
#    1196       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1150
#    1151     logging.info('Calling model_fn.')
# -> 1152     model_fn_results = self._model_fn(features=features, **kwargs)
#    1153     logging.info('Done calling model_fn.')
#    1154
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     762           dropout=dropout,
#     763           config=config,
# --> 764           batch_norm=batch_norm)
#     765
#     766     super(DNNClassifierV2, self).__init__(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in dnn_model_fn_v2(***failed resolving arguments***)
#     570       batch_norm=batch_norm,
#     571       features=features,
# --> 572       mode=mode)
#     573
#     574   # In TRAIN mode, create optimizer and assign global_step variable to
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _dnn_model_fn_builder_v2(units, hidden_units, feature_columns, activation_fn, dropout, batch_norm, features, mode)
#     505       dropout,
#     506       batch_norm,
# --> 507       name='dnn')
#     508   logits = dnn_model(features, mode)
#     509   trainable_variables = dnn_model.trainable_variables
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, batch_norm, name, **kwargs)
#     300       if feature_column_lib.is_feature_column_v2(feature_columns):
#     301         self._input_layer = dense_features_v2.DenseFeatures(
# --> 302             feature_columns=feature_columns, name=layer_name)
#     303       else:
#     304         raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\feature_column\dense_features_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      84         trainable=trainable,
#      85         name=name,
# ---> 86         **kwargs)
#      87     self._state_manager = fc._StateManagerImplV2(self, self.trainable)  # pylint: disable=protected-access
#      88
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\feature_column\dense_features.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      86         name=name,
#      87         expected_column_type=fc.DenseColumn,
# ---> 88         **kwargs)
#      89
#      90   @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     388             'You can wrap a categorical column with an '
#     389             'embedding_column or indicator_column. Given: {}'.format(
# --> 390                 expected_column_type, column))
#     391
#     392   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group,dimension=4)

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,embedded_group_col,age_bucket]

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(X_train,y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,20,20,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbs9ea0w5
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Public\\Documents\\Wondershare\\CreatorTemp\\tmpbs9ea0w5', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbs9ea0w5\model.ckpt.
# INFO:tensorflow:loss = 0.6895727, step = 0
# INFO:tensorflow:global_step/sec: 165.838
# INFO:tensorflow:loss = 0.68105996, step = 100 (0.602 sec)
# INFO:tensorflow:global_step/sec: 203.252
# INFO:tensorflow:loss = 0.6799784, step = 200 (0.492 sec)
# INFO:tensorflow:global_step/sec: 209.205
# INFO:tensorflow:loss = 0.7167584, step = 300 (0.478 sec)
# INFO:tensorflow:global_step/sec: 210.083
# INFO:tensorflow:loss = 0.66075945, step = 400 (0.477 sec)
# INFO:tensorflow:global_step/sec: 214.134
# INFO:tensorflow:loss = 0.64415246, step = 500 (0.467 sec)
# INFO:tensorflow:global_step/sec: 220.263
# INFO:tensorflow:loss = 0.6677701, step = 600 (0.453 sec)
# INFO:tensorflow:global_step/sec: 220.264
# INFO:tensorflow:loss = 0.66526145, step = 700 (0.454 sec)
# INFO:tensorflow:global_step/sec: 212.766
# INFO:tensorflow:loss = 0.635481, step = 800 (0.471 sec)
# INFO:tensorflow:global_step/sec: 209.205
# INFO:tensorflow:loss = 0.6997615, step = 900 (0.477 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbs9ea0w5\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.67323095.

# %%
eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-05-16T18:08:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbs9ea0w5\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.05735s
# INFO:tensorflow:Finished evaluation at 2020-05-16-18:08:46
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.64935064, accuracy_baseline = 0.64935064, auc = 0.6099589, auc_precision_recall = 0.42723376, average_loss = 0.64684266, global_step = 1000, label/mean = 0.35064936, loss = 0.6536763, precision = 0.0, prediction/mean = 0.40635097, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmpbs9ea0w5\model.ckpt-1000
# {'accuracy': 0.64935064,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.6099589,
#  'auc_precision_recall': 0.42723376,
#  'average_loss': 0.64684266,
#  'label/mean': 0.35064936,
#  'loss': 0.6536763,
#  'precision': 0.0,
#  'prediction/mean': 0.40635097,
#  'recall': 0.0,
#  'global_step': 1000}
